// %%
sysuse auto
// Out:
// (1978 Automobile Data)

// %%
save auto, replace
// Out:
// (note: file auto.dta not found)
// file auto.dta saved

// %%
scatter price mpg,graphregion(color(white))
// Out:
// This front-end cannot display the desired image type.
