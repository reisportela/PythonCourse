# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6])
ax = plt.gca()
line = ax.lines[0]
line.get_xydata()
# Out:
# array([[1., 4.],
#        [2., 5.],
#        [3., 6.]])

# %%
sysuse auto, clear
save auto, replace

scatter price mpg,graphregion(color(white))

serset use, clear
//list
export excel using "asd.xlsx", firstrow(variables) replace
# Out:
# (1978 Automobile Data)
#
# file auto.dta saved
# This front-end cannot display the desired image type.
#      +--------------+
#      |  price   mpg |
#      |--------------|
#   1. |  4,099    22 |
#   2. |  4,749    17 |
#   3. |  3,799    22 |
#   4. |  4,816    20 |
#   5. |  7,827    15 |
#      |--------------|
#   6. |  5,788    18 |
#   7. |  4,453    26 |
#   8. |  5,189    20 |
#   9. | 10,372    16 |
#  10. |  4,082    19 |
#      |--------------|
#  11. | 11,385    14 |
#  12. | 14,500    14 |
#  13. | 15,906    21 |
#  14. |  3,299    29 |
#  15. |  5,705    16 |
#      |--------------|
#  16. |  4,504    22 |
#  17. |  5,104    22 |
#  18. |  3,667    24 |
#  19. |  3,955    19 |
#  20. |  3,984    30 |
#      |--------------|
#  21. |  4,010    18 |
#  22. |  5,886    16 |
#  23. |  6,342    17 |
#  24. |  4,389    28 |
#  25. |  4,187    21 |
#      |--------------|
#  26. | 11,497    12 |
#  27. | 13,594    12 |
#  28. | 13,466    14 |
#  29. |  3,829    22 |
# ...

# %%
import pandas as pd
df = pd.read_stata('auto.dta')

# %%
df.mean()
# Out:
# price           6165.256757
# mpg               21.297297
# rep78              3.405797
# headroom           2.993243
# trunk             13.756757
# weight          3019.459459
# length           187.932432
# turn              39.648649
# displacement     197.297297
# gear_ratio         3.014865
# dtype: float64

# %%
plt.plot(df.price,df.mpg)
ax = plt.gca()
line = ax.lines[0]
dd = pd.DataFrame(line.get_xdata())

# %%
dd.mean()
# Out:
# 0    6165.256757
# dtype: float64

# %%
dd.to_csv('dd.csv')

# %%
plt.hist(df.price)
ax = plt.gca()
p = ax.patches
a = p[3].get_xy()
dd = pd.DataFrame(line.get_xdata())

# %%
# Out:
# 0    6165.256757
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
from sklearn.neighbors import KernelDensity

# %%
a
# Out:
# (7075.5, 0.0)

# %%
import matplotlib.pyplot as plt
counts, bins, bars = plt.hist(df.price, bins=5)
df2 = pd.DataFrame({'bin_leftedge': bins[:-1], 'count': counts})
df2.to_excel('df.xlsx')

# %%
df
# Out:
#     bin_leftedge  count
# 0       3291.000    2.0
# 1       3606.375    6.0
# 2       3921.750   11.0
# 3       4237.125    9.0
# 4       4552.500    7.0
# 5       4867.875    5.0
# 6       5183.250    4.0
# 7       5498.625    5.0
# 8       5814.000    2.0
# 9       6129.375    5.0
# 10      6444.750    1.0
# 11      6760.125    1.0
# 12      7075.500    1.0
# 13      7390.875    0.0
# 14      7706.250    1.0
# 15      8021.625    1.0
# 16      8337.000    0.0
# 17      8652.375    1.0
# 18      8967.750    0.0
# 19      9283.125    0.0
# 20      9598.500    2.0
# 21      9913.875    0.0
# 22     10229.250    2.0
# 23     10544.625    0.0
# 24     10860.000    0.0
# 25     11175.375    1.0
# 26     11490.750    1.0
# 27     11806.125    1.0
# 28     12121.500    0.0
# 29     12436.875    0.0
# 30     12752.250    1.0
# 31     13067.625    0.0
# 32     13383.000    2.0
# 33     13698.375    0.0
# 34     14013.750    0.0
# 35     14329.125    1.0
# 36     14644.500    0.0
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

counts, bins, bars = fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-ac872caea192> in <module>
#      24 #ax.bar_label(rects2, padding=3)
#      25
# ---> 26 counts, bins, bars = fig.tight_layout()
#      27
#      28 plt.show()
#
# TypeError: cannot unpack non-iterable NoneType object
